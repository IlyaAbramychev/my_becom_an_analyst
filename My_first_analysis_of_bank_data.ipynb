# %% [markdown]
# <div style="border:solid green 3px; padding: 20px">
#
# <b>Привет!</b>
#
# Меня зовут Сороколетов Илья и я буду проверять твой проект.
#
# Предлагаю общаться на «**ты**», но если тебе будет комфортнее общаться на «**вы**», то сообщи об этом в комментариях)
#
#
# Для твоего удобства, я буду выделять свои комментарии следующим образом:
#
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b> Самые важные замечания. Они указывают на ключевые моменты, которые влияют на конечный результат проекта. </div>
#
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b> Советы или замечания, которые помогут сделать твою работу лучше, но необязательны к выполнению.
#
# </div>
#
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b> Так я выделяю все остальные комментарии.</div>
#
#
# Пометками <b>v1-v2-v3-...</b> я буду отмечать версию проверки. Так ты сможешь быстро найти мои новые комментарии.
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом. Выбери для своих комментариев какой-то заметный цвет, так мне будет легче отследить изменения, например вот так:
#
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>
# </div>
#
# <b>Пожалуйста, не перемещай, не изменяй и не удаляй мои комментарии.</b> Если ты оставляешь свои комментарии, то делай это под моими, чтобы сообщения были расположены в хронологическом порядке. Всё это поможет выполнить повторную проверку твоего проекта быстрее.
#
# Перед отправкой работы я рекомендую нажимать Kernel -> Restart & Run All. Это перезапустит ядро и по очереди выполнит все ячейки. Так ты сможешь проверить, что всё работает корректно. Кнопка Kernel находится в панели сверху
#
# Обязательно задавай вопросы если они возникнут, а я перехожу к проверке)
#
# P.S. На всякий случай, я оставлю пустой шаблон для твоих комментариев ниже. Кликни два раза на мой комментарий, скопируй последние четыре строчки кода и вставляй их в пустую ячейку там, где ты хочешь оставить комментарий. Не забудь только перед этим сменить тип ячейки на Markdown. Быстро это можно сделать так: кликнуть на ячейку - нажать ESC - нажать M.
#
#
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Удали этот текст и вместо него напиши свой комментарий 🙂
# </div>

# %% [markdown]
# ## **Описание проекта: оценка рисков невозврата кредита**
#
# В вашем распоряжении данные клиентов банка «Скрудж», которые планируют взять кредит. Вам необходимо выяснить, что из имеющихся данных влияет на своевременное погашение кредита и каким именно образом.
#
# Исследование поможет в создании модели кредитного скоринга — системы для оценки способности потенциального заёмщика погасить свой кредит.
#
# По каждому клиенту есть информация о его семейном положении, образовании, доходе и другие данные. Вам предстоит подготовить данные к анализу и исследовать их, в процессе отвечая на вопросы.
#
# ### Описание данных
#
# - `children` — количество детей в семье;
# - `days_employed` — сколько дней работает клиент;
# - `dob_years` — возраст клиента;
# - `education` — уровень образования клиента;
# - `education_id` — идентификатор образования клиента;
# - `family_status` — семейное положение клиента;
# - `family_status_id` — идентификатор семейного положения клиента;
# - `gender` — пол клиента;
# - `income_type` — тип дохода клиента;
# - `debt` — был ли у клиента когда-либо просрочен платёж по кредиту;
# - `total_income` — ежемесячный доход;
# - `purpose` — причина оформления кредита.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Обрати внимание, что перед проектом расположено краткое описание задачи. Его важно добавлять перед каждым проектом (если его нет изначально). Это поможет тебе быстро вспомнить о чем проект, если спустя время ты решишь к нему вернуться)
# </div>

# %% [markdown]
# ## Шаг 1. Откройте файл с данными и изучите общую информацию
#
# 1. Загрузите датасет.
# 2. Сделайте копию датасета.
# 3. Изучите типы данных и определите, соответствуют ли они содержимому.
# 4. Напишите вывод.

# %%
# Импортируйте библиотеки для работы
# с таблицами и графиками
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Молодец, что импортируешь все библиотеки отдельно в первой ячейке. Это правило хорошего тона, которое позволит твоим коллегам сразу увидеть все необходимые библиотеки для работы с твоим файлом.
# </div>

# %%
# Загрузите датасет в переменную df_raw или другую по вашему выбору.
# Он доступен по адресу <https://code.s3.yandex.net/datasets/credit_scoring_eng.csv>
# а при работе на платформе по адресу /datasets/credit_scoring_eng.csv

df = pd.read_csv('/datasets/credit_scoring_eng.csv') #Запись файла  формата .csv в переменную df
df.head() #Вывод первых 5 строк датафрейма для проверки загрузки файла
# Out:
#    children  days_employed  dob_years            education  education_id  \
# 0         1   -8437.673028         42    bachelor's degree             0
# 1         1   -4024.803754         36  secondary education             1
# 2         0   -5623.422610         33  Secondary Education             1
# 3         3   -4124.747207         32  secondary education             1
# 4         0  340266.072047         53  secondary education             1
#
#        family_status  family_status_id gender income_type  debt  total_income  \
# 0            married                 0      F    employee     0     40620.102
# 1            married                 0      F    employee     0     17932.802
# 2            married                 0      M    employee     0     23341.752
# 3            married                 0      M    employee     0     42820.568
# 4  civil partnership                 1      F     retiree     0     25378.572
#
#                    purpose
# 0    purchase of the house
# ...

# %%
# При помощи метода .copy() скопируйте датасет
# для работы с ним в переменную df или другую

df_copy = df.copy() #Копирование датафрейма и запись в новую переменную df_copy
df_copy.head() #Вывод первых 5 строк df_copy для проверки загрузки файла
# Out:
#    children  days_employed  dob_years            education  education_id  \
# 0         1   -8437.673028         42    bachelor's degree             0
# 1         1   -4024.803754         36  secondary education             1
# 2         0   -5623.422610         33  Secondary Education             1
# 3         3   -4124.747207         32  secondary education             1
# 4         0  340266.072047         53  secondary education             1
#
#        family_status  family_status_id gender income_type  debt  total_income  \
# 0            married                 0      F    employee     0     40620.102
# 1            married                 0      F    employee     0     17932.802
# 2            married                 0      M    employee     0     23341.752
# 3            married                 0      M    employee     0     42820.568
# 4  civil partnership                 1      F     retiree     0     25378.572
#
#                    purpose
# 0    purchase of the house
# ...

# %%
# Изучите общую информацию о датасете
df_copy.info() #Вывод общей информации о датафреме(кол-во столбцов/кол-во строк/сколько занимает памяти/типы данных столбцов)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21525 non-null  int64
#  1   days_employed     19351 non-null  float64
#  2   dob_years         21525 non-null  int64
#  3   education         21525 non-null  object
#  4   education_id      21525 non-null  int64
#  5   family_status     21525 non-null  object
#  6   family_status_id  21525 non-null  int64
#  7   gender            21525 non-null  object
#  8   income_type       21525 non-null  object
#  9   debt              21525 non-null  int64
#  10  total_income      19351 non-null  float64
#  11  purpose           21525 non-null  object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>Тут необходимо написать короткий вывод о проблемах с данными (пропуски, дубликаты, неверный тип данных, странные значения и т.д.)
# </div>

# %% [markdown]
# ## Шаг 2. Выполните предобработку данных

# %% [markdown]
# 1. Найдите и изучите пропущенные значения в столбцах.
# 2. Устраните пропущенные значения: удалите или замените их.
# 3. Объясните выбранную стратегию обработки пропущенных значений.

# %%
# Место для вашего кода
df.isna().sum() #Из операции можно выделить две колонки (days_employed, total_income), которые имеют пропуски
# Out:
# children               0
# days_employed       2174
# dob_years              0
# education              0
# education_id           0
# family_status          0
# family_status_id       0
# gender                 0
# income_type            0
# debt                   0
# total_income        2174
# purpose                0
# dtype: int64

# %%
df[['days_employed', 'total_income']].isna().mean() # Доля пропусков для days_employed, total_income составляет 10%
# Out:
# days_employed    0.100999
# total_income     0.100999
# dtype: float64

# %%
df['days_employed'] = df['days_employed'].abs()     # Преобразование отрицаительных значений в положительные
df[['days_employed', 'total_income']].mean()
# Out:
# days_employed    66914.728907
# total_income     26787.568355
# dtype: float64

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Здорово, что ты используешь функцию abs чтобы избавиться от отрицательных значений!
# </div>

# %% [markdown]
# >Пропуски в столбцах days_employed, total_income одинаковы для определенного пользователя. Можно заменить на 0

# %%
df['days_employed'] = df['days_employed'].fillna(0)
df['total_income'] = df['total_income'].fillna(0)
df.head()
# Out:
#    children  days_employed  dob_years            education  education_id  \
# 0         1    8437.673028         42    bachelor's degree             0
# 1         1    4024.803754         36  secondary education             1
# 2         0    5623.422610         33  Secondary Education             1
# 3         3    4124.747207         32  secondary education             1
# 4         0  340266.072047         53  secondary education             1
#
#        family_status  family_status_id gender income_type  debt  total_income  \
# 0            married                 0      F    employee     0     40620.102
# 1            married                 0      F    employee     0     17932.802
# 2            married                 0      M    employee     0     23341.752
# 3            married                 0      M    employee     0     42820.568
# 4  civil partnership                 1      F     retiree     0     25378.572
#
#                    purpose
# 0    purchase of the house
# ...

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Ещё тут было бы допустимо заменить пропуски через медианы с группировкой по возрасту клиента
# </div>

# %% [markdown]
# 1. Изучите уникальные значения в столбцах с уровнем образования (`education`) и полом клиента (`gender`).
# 2. Устраните неявные дубликаты и некорректные значения.

# %%
# Место для вашего кода
df['education'].unique()
# Out:
# array(["bachelor's degree", 'secondary education', 'Secondary Education',
#        'SECONDARY EDUCATION', "BACHELOR'S DEGREE", 'some college',
#        'primary education', "Bachelor's Degree", 'SOME COLLEGE',
#        'Some College', 'PRIMARY EDUCATION', 'Primary Education',
#        'Graduate Degree', 'GRADUATE DEGREE', 'graduate degree'],
#       dtype=object)

# %%
df['gender'].unique()
# Out:
# array(['F', 'M', 'XNA'], dtype=object)

# %% [markdown]
# 1. Проверьте наличие дубликатов. Изучите дублированные данные, если они есть, и примите решение — удалять их или оставить.

# %%
# Место для вашего кода
df['education'] = df['education'].str.lower().str.replace("'", '').str.strip() # Первым этапом приводим к одному виду           
df['education'].unique()                                                       #     данные в колонке 'education'
# Out:
# array(['bachelors degree', 'secondary education', 'some college',
#        'primary education', 'graduate degree'], dtype=object)

# %%
df.groupby(by = ['gender', 'education'])['total_income'].mean()
# Out:
# gender  education
# F       bachelors degree       27119.437712
#         graduate degree        29345.394000
#         primary education      17359.110301
#         secondary education    20299.014342
#         some college           23995.913450
# M       bachelors degree       35089.790260
#         graduate degree        27267.340000
#         primary education      22598.985529
#         secondary education    25630.344311
#         some college           30158.761300
# XNA     some college           32624.825000
# Name: total_income, dtype: float64

# %%
# Количество XNA в столбце gender
df['gender'].value_counts()['XNA'] # В столбце gender содержится одна строка с 'XNA'
# Out:
# 1

# %%
df[df['gender'] == 'XNA'] # Находим строку для ознакомления с данными
# Out:
#        children  days_employed  dob_years     education  education_id  \
# 10701         0    2358.600502         24  some college             2
#
#            family_status  family_status_id gender income_type  debt  \
# 10701  civil partnership                 1    XNA    business     0
#
#        total_income          purpose
# 10701     32624.825  buy real estate

# %%
df = df[df['gender'] != 'XNA'] # 1 Строка не несет глубокого смысла, поэтому ее можно удалить

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Поддерживаю! Так как мы не можем достоверно сказать, к какому полу ближе это значение, его стоит удалить)
# </div>

# %% [markdown]
# ## Шаг 3. Выбросы и аномальные значения
#
# Изучите столбцы `total_income`, `dob_age`, `chidlren` на наличие выбросов и аномальных значений, в том числе при помощи графиков. Если выбросы или аномалии будут обнаружены — обоснованно примите решение об их судьбе. Используйте подзаголовки третьего уровня (`### Подзаголовок`), чтобы создать структуру действий в рамках этого шага.

# %% [markdown]
# ### Изучение total_income на наличие выбросов

# %%
# Место для вашего кода
sns.boxplot(data = df, x = 'total_income')

plt.title('Выбросы в total_income')
plt.show()

# %% [markdown]
# ### Изучение dob_years на наличие выбросов

# %%
sns.boxplot(data = df, x = 'dob_years')
# Средний возраст клиентов - 42 года. На графике присутствует выброс в районе 0 лет. Следует провести дополнительный анализ
plt.title('Выбросы в dob_years')
plt.show()

# %%
filt_years = df[df['dob_years']  > 18]['dob_years'].median()
df['dob_years'] = df['dob_years'].apply(lambda x: filt_years if x <= 18 else x)
df
# Out:
#        children  days_employed  dob_years            education  education_id  \
# 0             1    8437.673028       42.0     bachelors degree             0
# 1             1    4024.803754       36.0  secondary education             1
# 2             0    5623.422610       33.0  secondary education             1
# 3             3    4124.747207       32.0  secondary education             1
# 4             0  340266.072047       53.0  secondary education             1
# ...         ...            ...        ...                  ...           ...
# 21520         1    4529.316663       43.0  secondary education             1
# 21521         0  343937.404131       67.0  secondary education             1
# 21522         1    2113.346888       38.0  secondary education             1
# 21523         3    3112.481705       38.0  secondary education             1
# 21524         2    1984.507589       40.0  secondary education             1
#
# ...

# %%
sns.boxplot(data = df, x = 'dob_years')
# Операцией выше был заменен возраст ниже 18 лет на средний возраст по датасету (43 года). 
plt.title('Выбросы dob_years')  # Эта операция позволила избавиться от выбросов. 
plt.show()                      # Смотреть график:

# %% [markdown]
# ### Изучение children на наличие выбросов

# %%
sns.boxplot(data = df, x = 'children')
# Из графика понятно, что данные распределены хорошо, однако есть выброс в районе 20 лет, что является не детским возрастом, 
plt.title('Выбросы в children')                                                      # нужно провести дополнительный анализ
plt.show()

# %%
df.head()
# Out:
#    children  days_employed  dob_years            education  education_id  \
# 0         1    8437.673028       42.0     bachelors degree             0
# 1         1    4024.803754       36.0  secondary education             1
# 2         0    5623.422610       33.0  secondary education             1
# 3         3    4124.747207       32.0  secondary education             1
# 4         0  340266.072047       53.0  secondary education             1
#
#        family_status  family_status_id gender income_type  debt  total_income  \
# 0            married                 0      F    employee     0     40620.102
# 1            married                 0      F    employee     0     17932.802
# 2            married                 0      M    employee     0     23341.752
# 3            married                 0      M    employee     0     42820.568
# 4  civil partnership                 1      F     retiree     0     25378.572
#
#                    purpose
# 0    purchase of the house
# ...

# %%
median_age = df[(df['children'] > 0) & (df['children'] < 20)]['children'].median()
df['children'] = df['children'].apply(lambda x: median_age if x == -1 or x == 20 else x)
# Для ухода от большого разброса и уничтожения отрицаительных данных, задача решается с помощью замены на median
sns.boxplot(data = df, x = 'children')
plt.title('Выбросы в children')
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Отличная работа с аномальными данными 👍
# </div>

# %% [markdown]
# ## Шаг 4. Добавьте в таблицу новые столбцы

# %% [markdown]
# 1. **Разделите клиентов на 5 категорий по уровню дохода:**
# - Без дохода — люди без работы и с нулевым доходом.
# - Очень низкий доход — люди, получающие ниже 14 процентиля от общего распределения дохода.
# - Низкий доход — люди, получающие между 14 и 34 процентилями от общего распределения дохода.
# - Средний доход — люди, получающие между 34 и 78 процентилями от общего распределения дохода.
# - Высокий доход — люди, получающие больше 78 процентиля от общего распределения дохода.

# %%
df['dob_years'] = df['dob_years'].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21524 entries, 0 to 21524
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21524 non-null  float64
#  1   days_employed     21524 non-null  float64
#  2   dob_years         21524 non-null  int64
#  3   education         21524 non-null  object
#  4   education_id      21524 non-null  int64
#  5   family_status     21524 non-null  object
#  6   family_status_id  21524 non-null  int64
#  7   gender            21524 non-null  object
#  8   income_type       21524 non-null  object
#  9   debt              21524 non-null  int64
#  10  total_income      21524 non-null  float64
#  11  purpose           21524 non-null  object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 2.1+ MB

# %%
# Место для вашего кода
import numpy as np

p0 = df['total_income'].quantile(0.0)
p14 = df['total_income'].quantile(0.14)
p34 = df['total_income'].quantile(0.34)
p78 = df['total_income'].quantile(0.78)
    
def income_level(row, p0, p14, p34, p78):
    
    """Функция для категоризации людей по их доходу:
       - Без дохода — люди без работы и с нулевым доходом.
       - Очень низкий доход — люди, получающие ниже 14 процентиля от общего распределения дохода.
       - Низкий доход — люди, получающие между 14 и 34 процентилями от общего распределения дохода.
       - Средний доход — люди, получающие между 34 и 78 процентилями от общего распределения дохода.
       - Высокий доход — люди, получающие больше 78 процентиля от общего распределения дохода."""
    
    total_income = row['total_income']
    
    if total_income <= p0:
        return 'Без дохода'
    elif total_income <= p14:
        return 'Очень низкий доход'
    elif total_income <= p34:
        return 'Низкий доход'
    elif total_income <= p78:
        return 'Средний доход'
    else:
        return 'Высокий доход'
    
df['calculation_income'] = df.apply(income_level, axis = 1, args = (p0, p14, p34, p78))
df.sample(5)
# Out:
#        children  days_employed  dob_years            education  education_id  \
# 9617        1.0    2360.703095         30     bachelors degree             0
# 18491       0.0  366524.770381         48     bachelors degree             0
# 8962        1.0    3584.381405         35  secondary education             1
# 9121        0.0     569.836162         30  secondary education             1
# 18860       2.0     396.946895         31     bachelors degree             0
#
#       family_status  family_status_id gender income_type  debt  total_income  \
# 9617        married                 0      F    employee     0     13785.307
# 18491       married                 0      M     retiree     0     42087.690
# 8962       divorced                 3      M    employee     0     39796.827
# 9121        married                 0      M    employee     0     21114.695
# 18860       married                 0      F    employee     0     21823.778
#
# ...

# %% [markdown]
# 1. Разделите клиентов на две категории по возрасту: до 40 лет и после. Сохраните результат в колонке `age_category`.

# %%
# Место для вашего кода
def customer_separation(row):
     
    """Функция для разделения людей на две категории:
    - До 40 лет;
    - После 40 лет."""
    
    dob_years = row['dob_years']
    
    if dob_years < 40:
        return 'До 40 лет'
    elif dob_years >= 40:
        return 'После 40 лет'
    else:
        return 'Неверный возраст'
    
    
    
    
    
df['age_category'] = df.apply(customer_separation, axis = 1)
df.sample(5)
# Out:
#        children  days_employed  dob_years            education  education_id  \
# 1223        0.0    6855.901021         43  secondary education             1
# 9364        0.0     681.276659         36  secondary education             1
# 19815       0.0     285.948914         51  secondary education             1
# 1179        1.0     669.053082         41     bachelors degree             0
# 13426       3.0     370.917993         31     bachelors degree             0
#
#            family_status  family_status_id gender income_type  debt  \
# 1223             married                 0      F    employee     0
# 9364             married                 0      F    employee     0
# 19815            married                 0      F    employee     1
# 1179             married                 0      M    business     1
# 13426  civil partnership                 1      F    employee     0
#
#        total_income                      purpose calculation_income  \
# ...

# %% [markdown]
# 1. Разделите клиентов на несколько категорий по количеству детей: без детей, от одного до двух, от трёх и больше. Сохраните результат в колонке `childrens_category`.

# %%
# Место для вашего кода
def count_children(row):
    
    """Функция для разделения на категории по количеству детей:
    - Без детей;
    - От отдного до двух детей;
    - От трёх и больше детей."""
    
    children = row['children']
    
    if children <= 0:
        return 'Без детей'
    elif children >= 1 and children <= 2:
        return 'От одного до двух детей'
    elif children >= 3:
        return 'От трёх и больше детей'
    else:
        return 'Неверно'
    
    
df['childrens_category'] = df.apply(count_children, axis = 1)
df.sample(5)
# Out:
#        children  days_employed  dob_years            education  education_id  \
# 4624        0.0    5730.775717         52     bachelors degree             0
# 1892        0.0     153.548771         33     bachelors degree             0
# 12842       0.0    1613.057434         22  secondary education             1
# 21375       0.0    1381.847960         49  secondary education             1
# 1258        2.0    6450.804889         45     bachelors degree             0
#
#            family_status  family_status_id gender    income_type  debt  \
# 4624           unmarried                 4      M       employee     0
# 1892            divorced                 3      M       business     0
# 12842          unmarried                 4      M       business     0
# 21375  civil partnership                 1      M       employee     1
# 1258            divorced                 3      F  civil servant     0
#
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Категоризация произведена верно!
# </div>

# %% [markdown]
# ## Шаг 5. Проведите исследовательский анализ данных

# %% [markdown]
# Задайте структуру наиболее объёмной части исследования. Исследуйте факторы: `Уровень дохода`, `Образование`, `Возраст`, `Количество детей`. Отличается ли распределение между должниками и нет? Исследуйте вопрос графически. Постройте сводную таблицу по каждому фактору и покажите, как часто встречаются должники в каждой группе клиентов. Выберите подходящую визуализацию и сравните 2 группы.

# %%
# Место для вашего кода
grouped_table = pd.pivot_table(df,
                               index = ['calculation_income', 'education', 'age_category', 'childrens_category'],
                               values='debt',
                               aggfunc='mean').reset_index()
grouped_table
# Out:
#     calculation_income         education  age_category  \
# 0           Без дохода  bachelors degree     До 40 лет
# 1           Без дохода  bachelors degree     До 40 лет
# 2           Без дохода  bachelors degree     До 40 лет
# 3           Без дохода  bachelors degree  После 40 лет
# 4           Без дохода  bachelors degree  После 40 лет
# ..                 ...               ...           ...
# 106      Средний доход      some college     До 40 лет
# 107      Средний доход      some college     До 40 лет
# 108      Средний доход      some college  После 40 лет
# 109      Средний доход      some college  После 40 лет
# 110      Средний доход      some college  После 40 лет
#
#           childrens_category      debt
# 0                  Без детей  0.053030
# 1    От одного до двух детей  0.038760
# 2     От трёх и больше детей  0.125000
# 3                  Без детей  0.045000
# 4    От одного до двух детей  0.055556
# ..                       ...       ...
# ...

# %%
plt.figure(figsize = (20, 15))
sns.barplot(data = grouped_table, x = 'calculation_income', y = 'debt', hue = 'education')
plt.title('Распределение должников')
plt.show()

# %% [markdown]
# > ###### На графике показано, что люди с образование some college и высоким уровнем дохода имеют более высокий риск просрочек по кредиту. Также, людей с образованием primary education и без дохода можно отнести к группе с высоким риском просрочек по кредиту.

# %%
plt.figure(figsize = (20, 15))
sns.barplot(data = grouped_table, x = 'calculation_income', y = 'debt', hue = 'age_category')
plt.title('Распределение должников')
plt.show()

# %% [markdown]
# > ###### Из графика можно сделать вывод, что категория людей до 40 лет наиболее подвержена просрочке оплате кредита, за исключением группы людей с очень низким доходом. Люди с категорией без дохода имет самый высокий показатель просрочек по кредиту.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Отличные графики и выводы!
# </div>

# %% [markdown]
# ***Проверьте исследовательскую гипотезу***: у клиентов с детьми более высокий уровень финансовой ответственности и, следовательно, более низкий риск просрочек по кредиту.

# %%
# Место для вашего кода
plt.figure(figsize = (20, 15))
sns.barplot(data = grouped_table, x = 'age_category', y = 'debt', hue = 'childrens_category')
plt.title('Распределение должников')
plt.show()

# %% [markdown]
# > ###### Из данных видно, что у клиентов с детьми уровень финансовой ответственности ниже, и следовательно, более высокий риск просрочек по кредиту

# %% [markdown]
# ***Проверьте исследовательскую гипотезу***: одинокие мужчины с низким доходом чаще оказываются должниками, чем семейные мужчины со средним доходом.

# %%
# Место для вашего кода
grouped_table_hip = pd.pivot_table(df,
                               index = ['calculation_income', 'family_status', 'gender', 'childrens_category'],
                               values='debt',
                               aggfunc='mean').reset_index()
grouped_table_hip
# Out:
#     calculation_income      family_status gender       childrens_category  \
# 0           Без дохода  civil partnership      F                Без детей
# 1           Без дохода  civil partnership      F  От одного до двух детей
# 2           Без дохода  civil partnership      F   От трёх и больше детей
# 3           Без дохода  civil partnership      M                Без детей
# 4           Без дохода  civil partnership      M  От одного до двух детей
# ..                 ...                ...    ...                      ...
# 124      Средний доход    widow / widower      F                Без детей
# 125      Средний доход    widow / widower      F  От одного до двух детей
# 126      Средний доход    widow / widower      F   От трёх и больше детей
# 127      Средний доход    widow / widower      M                Без детей
# 128      Средний доход    widow / widower      M  От одного до двух детей
#
#          debt
# 0    0.073529
# 1    0.117647
# 2    0.333333
# 3    0.142857
# ...

# %%
plt.figure(figsize = (20, 15))
sns.barplot(data = grouped_table_hip,
            x = 'calculation_income',
            y = 'debt',
            hue = 'family_status')
plt.title('Распределение должников')
plt.show()

# %%
plt.figure(figsize = (20, 15))
sns.barplot(data = grouped_table_hip,
            x = 'gender',
            y = 'debt',
            hue = 'family_status')
plt.title('Распределение должников')
plt.show()

# %% [markdown]
# > ###### Из двух графиков можно сделать вывод, что одинокие мужчины (unmarried) со средним доходом имеют более высокий риск просрочки по кредиту. Можно подтвердить гипотезу, что одинокие мужчины с низким доходом чаще оказываются должниками, чем семейные мужчины со средним доходом.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Верно! 👍
# </div>

# %% [markdown]
# ## Шаг 6. Напишите общий вывод

# %% [markdown]
# **В итоговом проекте было проведено исследование кредитных рисков.**
#
# ***В ходе исследования датасета, было выявлено ряд проблем:***
#
# ***Обнаружены*** пропуски в двух колонках `days_employed`, `total_income`. Доля пропусков составила 10% для каждой колонки. В `days_employed` были исправлены отрицательные значения на положительные. Пропуски в столбцах `days_employed`, `total_income` одинаковы для определенного пользователя. Проведена замена на 0.
#
#  ***Изучены*** `education` и `gender`. Выявлено, что `education` имеет более 15 уникальных значений и они являются дубликатами. `Gender` имеет 3 категории вместо 2. Проведена работа с `education` и после преобразований дубликатов на выходе получилось 5 видов образования. Изучена колонка `gender` и стало понятно, что данный класс 'XNA' является выбросом. Удален из колонки `gender`.
#
# ***Далее*** проанализированы `total_income`, `dob_years`, `children`. В ***total_income*** не обнаружено аномалий и выбросов. Значения свыше 300000 у.е. посчитались корректными значениями, так как два человека, которые имеют такой доход, работают в сфере, связанной с бизнесом, имеют высшее образование и женаты. В ***dob_years*** присутствует выброс в районе 0 лет. Был заменен возраст ниже 18 лет на средний возраст по датасету (43 года). Эта операция позволила избавиться от выбросов. При работе с `children` стало понятно, что данные распределены хорошо, однако есть выброс в районе 20 лет, что является не детским возрастом. Для ухода от большого разброса и уничтожения отрицательных данных, задача решается с помощью замены на медианное значение.
#
# ***Следующим шагом для более глубокого анализа было предпринято:***
#
# 1. Разделение клиентов на 5 категорий по уровню дохода:
#     - Без дохода — люди без работы и с нулевым доходом.
#     - Очень низкий доход — люди, получающие ниже 14 процентиля от общего распределения дохода.
#     - Низкий доход — люди, получающие между 14 и 34 процентилями от общего распределения дохода.
#     - Средний доход — люди, получающие между 34 и 78 процентилями от общего распределения дохода.
#     - Высокий доход — люди, получающие больше 78 процентиля от общего распределения дохода.
#
# 2. Разделение клиентов на две категории по возрасту: до 40 лет и после.
#
# 3. Разделение клиентов на несколько категорий по количеству детей:
#     - Без детей.
#     - От одного до двух.
#     - От трёх и больше.
#
# ***Проведен исследовательский анализ.*** Исследованы факторы: Уровень дохода, Образование, Возраст, Количество детей. Построена сводная таблица по каждому фактору и показано, как часто встречаются должники в каждой группе клиентов. Представлены столбчатые диаграммы для более интуитивного понимания. Выявлено, что люди с образованием `some college` и высоким уровнем дохода имеют более высокий риск просрочек по кредиту. Также, людей с образованием `primary education` и без дохода можно отнести к группе с высоким риском просрочек по кредиту. Также из графика можно сделать вывод, что категория людей до 40 лет наиболее подвержена просрочке оплаты кредита, за исключением группы людей с очень низким доходом. Люди с категорией без дохода имеют самый высокий показатель просрочек по кредиту.
#
# ***В ходе подтверждения/опровержения гипотез:***
#
# - ***Проверьте исследовательскую гипотезу***:у клиентов с детьми более высокий уровень финансовой ответственности и, следовательно, более низкий риск просрочек по кредиту.
#   ***Ответ:*** Из данных видно, что у клиентов с детьми уровень финансовой ответственности ниже, и, следовательно, более высокий риск просрочек по кредиту.
#
# - ***Проверьте исследовательскую гипотезу***:одинокие мужчины с низким доходом чаще оказываются должниками, чем семейные мужчины со средним доходом.
#   ***Ответ:*** Из двух графиков можно сделать вывод, что одинокие мужчины (`unmarried`) со средним доходом имеют более высокий риск просрочки по кредиту. Можно подтвердить гипотезу, что одинокие мужчины с низким доходом чаще оказываются должниками, чем семейные мужчины со средним доходом.

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Итоговый комментарий ревьюера v1:</b>
# <br>Необходимо поправить:
# <br>- написать вывод после первичного анализа данных
#
# </div>

# %% [markdown]
# ## *Шаг 7. Проведите дополнительное исследование

# %% [markdown]
# (Необязательное задание) Исследуйте причины оформления кредита. Правда ли, что люди, которые брали кредит на образование, реже всего оказывались должниками?

# %%
# Изучите уникальные значения в поле purpose

# %%
# Разделите клиентов на 2 группы
def find_education_purpose(purpose):
  pass

# %%
# Исследуйте полученные группы по доле не вернувших кредит

# %% [markdown]
# ---
